# %% [markdown]
# # 2x2 Pure Weak Nash Equilibrium

# %%
import numpy as np
from IPython import display
from TwoTimesTwoGamesFunctions import updateStrategy, plot, trajectory, plotTrajectory, computeStablePoints, plotStableRegion, checkStability, calculateFrequencies, plotFrequencies, project

# %%
display.Image("PayoffMatrices/Weak2x2.png", width = 300)

# %%
######### Initialization ######### (note: utility maximization)

# player 1:
payoff1 = np.array([[1,1],[2,1]])

# player 2:
payoff2 = np.array([[0,2],[2,2]])

#number of iterations
iterations = int(200)

#number of vectors in the plot = gridSize^2
gridSize = 15

#game title
gameName = "Weak2x2"

#name of first strategy 
nameOfStrategy1 = "H"
nameOfStrategy2 = "H"

######### Equilibria #########

#Pure Nash Equilibria
pne = [[0,0]]

#Mixed Nash Equilibria 
#sytax: (..., (P1(strategy1),P2(strategy1)), ... )
mne = [[0.5,0.5]]

# %%
########## Online Mirror Ascent One Update Step #############

diff1, diff2 = updateStrategy(iterations, gridSize, payoff1, payoff2, "POGA")

# %%
#quiver plot
#note plotType should be "quiver" or "stream"
#The last three argument are optional. If a stable regions w.r.t some Nash Equilibria
#should be plotted they all three have to be provided
plot(gridSize, diff1, diff2, pne, mne, gameName, nameOfStrategy1, nameOfStrategy2, "POGA", "stream",
        )

# %%
########## Online Mirror Ascent One Update Step #############

diff1, diff2 = updateStrategy(iterations, gridSize, payoff1, payoff2, "EGA")

# %%
#quiver plot
#note plotType should be "quiver" or "stream"
#The last three argument are optional. If a stable regions w.r.t some Nash Equilibria
#should be plotted they all three have to be provided
plot(gridSize, diff1, diff2, pne, mne, gameName, nameOfStrategy1, nameOfStrategy2, "EGA", "stream")

# %%
#quiver plot
#note plotType should be "quiver" or "stream"
#The last three argument are optional. If a stable regions w.r.t some Nash Equilibria
#should be plotted they all three have to be provided
plot(gridSize, diff1, diff2, pne, mne, gameName, nameOfStrategy1, nameOfStrategy2, "EGA", "stream",
     payoff1, payoff2, [pne[0]])

# %%
#quiver plot
#note plotType should be "quiver" or "stream"
#The last three argument are optional. If a stable regions w.r.t some Nash Equilibria
#should be plotted they all three have to be provided
plot(gridSize, diff1, diff2, pne, mne, gameName, nameOfStrategy1, nameOfStrategy2, "EGA", "stream",
     payoff1, payoff2, [mne[0]])

# %%
#plotting a single trajectory

p1Init = 0.9
p2Init = 0.9

p1, p2 = trajectory(p1Init, p2Init, iterations, payoff1, payoff2, "EGA")
plotTrajectory(p1Init, p2Init, p1, p2, pne, mne, gameName, nameOfStrategy1, nameOfStrategy2, "EGA")
